# %% [markdown]
# Leitura e limpeza de dados
#
# Arquivo que contem as viagens

# %%
#importing libraries
import pandas as pd

# %matplotlib inline

# %%
# Resposta:

from google.colab import drive
drive.mount('/content/drive')

# lê o arquivo CSV
df = pd.read_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/2022_Pagamento.csv', encoding='latin-1', sep=';')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Índices
#
# Definindo indice para o ordenação

# %%
df = df.set_index('Identificador do processo de viagem')
df = df.sort_index()

df
# Out:
#                                     Número da Proposta (PCDP)  \
# Identificador do processo de viagem
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# ...                                                       ...
# 2022000496                                     Sem informação
# 2022000496                                     Sem informação
# 2022000518                                     Sem informação
# 2022000542                                     Sem informação
# 2022000542                                     Sem informação
#
#                                      Código do órgão superior  \
# Identificador do processo de viagem
# 17503013                                                   -1
# 17503013                                                   -1
# 17503013                                                   -1
# 17503013                                                   -1
# 17503013                                                   -1
# ...                                                       ...
# 2022000496                                              25201
# 2022000496                                              25201
# 2022000518                                              25201
# 2022000542                                              25201
# 2022000542                                              25201
#
#                                                                 Nome do órgão superior  \
# Identificador do processo de viagem
# 17503013                                                                      Sigiloso
# 17503013                                                                      Sigiloso
# 17503013                                                                      Sigiloso
# 17503013                                                                      Sigiloso
# 17503013                                                                      Sigiloso
# ...                                                                                ...
# 2022000496                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000496                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000518                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000542                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000542                           Banco Central do Brasil - Orçamento Fiscal e S...
#
#                                      Codigo do órgão pagador  \
# Identificador do processo de viagem
# 17503013                                                  -1
# 17503013                                                  -1
# 17503013                                                  -1
# 17503013                                                  -1
# 17503013                                                  -1
# ...                                                      ...
# 2022000496                                             25201
# 2022000496                                             25201
# 2022000518                                             25201
# 2022000542                                             25201
# 2022000542                                             25201
#
#                                                                  Nome do órgao pagador  \
# Identificador do processo de viagem
# 17503013                                                                           NaN
# 17503013                                                                           NaN
# 17503013                                                                           NaN
# 17503013                                                                           NaN
# 17503013                                                                           NaN
# ...                                                                                ...
# 2022000496                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000496                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000518                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000542                           Banco Central do Brasil - Orçamento Fiscal e S...
# 2022000542                           Banco Central do Brasil - Orçamento Fiscal e S...
#
#                                      Código da unidade gestora pagadora  \
# Identificador do processo de viagem
# 17503013                                                            -11
# 17503013                                                            -11
# 17503013                                                            -11
# 17503013                                                            -11
# 17503013                                                            -11
# ...                                                                 ...
# 2022000496                                                       173057
# 2022000496                                                       173057
# 2022000518                                                       173057
# 2022000542                                                       173057
# 2022000542                                                       173057
#
#                                     Nome da unidade gestora pagadora  \
# Identificador do processo de viagem
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# ...                                                              ...
# 2022000496                                   BANCO CENTRAL DO BRASIL
# 2022000496                                   BANCO CENTRAL DO BRASIL
# 2022000518                                   BANCO CENTRAL DO BRASIL
# 2022000542                                   BANCO CENTRAL DO BRASIL
# 2022000542                                   BANCO CENTRAL DO BRASIL
#
#                                     Tipo de pagamento    Valor
# Identificador do processo de viagem
# 17503013                                      DIÁRIAS   100,30
# 17503013                                      DIÁRIAS   633,91
# 17503013                                      DIÁRIAS  2781,70
# 17503013                                      DIÁRIAS  2758,97
# 17503013                                      DIÁRIAS  1614,18
# ...                                               ...      ...
# 2022000496                                    DIÁRIAS   635,15
# 2022000496                                   PASSAGEM  2352,19
# 2022000518                                    DIÁRIAS   434,50
# 2022000542                                   PASSAGEM  2174,79
# 2022000542                                    DIÁRIAS   290,93
#
# [604663 rows x 9 columns]

# %% [markdown]
# # Verificando informações do arquivo e conferindo se o Dtype esta correto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 604663 entries, 17503013 to 2022000542
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Número da Proposta (PCDP)           604663 non-null  object
#  1   Código do órgão superior            604663 non-null  int64
#  2   Nome do órgão superior              604663 non-null  object
#  3   Codigo do órgão pagador             604663 non-null  int64
#  4   Nome do órgao pagador               493622 non-null  object
#  5   Código da unidade gestora pagadora  604663 non-null  int64
#  6   Nome da unidade gestora pagadora    604663 non-null  object
#  7   Tipo de pagamento                   604663 non-null  object
#  8   Valor                               604663 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 46.1+ MB

# %% [markdown]
# Verificando se apresenta linhas com NaN no arquivo

# %%
df[df.isna().any(axis=1)]
# Out:
#                                     Número da Proposta (PCDP)  \
# Identificador do processo de viagem
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# 17503013                                      Informações pro
# ...                                                       ...
# 18394132                                      Informações pro
# 2022000469                                     Sem informação
# 2022000469                                     Sem informação
# 2022000470                                     Sem informação
# 2022000470                                     Sem informação
#
#                                      Código do órgão superior  \
# Identificador do processo de viagem
# 17503013                                                   -1
# 17503013                                                   -1
# 17503013                                                   -1
# 17503013                                                   -1
# 17503013                                                   -1
# ...                                                       ...
# 18394132                                                   -1
# 2022000469                                                 -1
# 2022000469                                                 -1
# 2022000470                                                 -1
# 2022000470                                                 -1
#
#                                     Nome do órgão superior  \
# Identificador do processo de viagem
# 17503013                                          Sigiloso
# 17503013                                          Sigiloso
# 17503013                                          Sigiloso
# 17503013                                          Sigiloso
# 17503013                                          Sigiloso
# ...                                                    ...
# 18394132                                          Sigiloso
# 2022000469                                  Sem informação
# 2022000469                                  Sem informação
# 2022000470                                  Sem informação
# 2022000470                                  Sem informação
#
#                                      Codigo do órgão pagador  \
# Identificador do processo de viagem
# 17503013                                                  -1
# 17503013                                                  -1
# 17503013                                                  -1
# 17503013                                                  -1
# 17503013                                                  -1
# ...                                                      ...
# 18394132                                                  -1
# 2022000469                                                -3
# 2022000469                                                -3
# 2022000470                                                -3
# 2022000470                                                -3
#
#                                     Nome do órgao pagador  \
# Identificador do processo de viagem
# 17503013                                              NaN
# 17503013                                              NaN
# 17503013                                              NaN
# 17503013                                              NaN
# 17503013                                              NaN
# ...                                                   ...
# 18394132                                              NaN
# 2022000469                                            NaN
# 2022000469                                            NaN
# 2022000470                                            NaN
# 2022000470                                            NaN
#
#                                      Código da unidade gestora pagadora  \
# Identificador do processo de viagem
# 17503013                                                            -11
# 17503013                                                            -11
# 17503013                                                            -11
# 17503013                                                            -11
# 17503013                                                            -11
# ...                                                                 ...
# 18394132                                                            -11
# 2022000469                                                           -3
# 2022000469                                                           -3
# 2022000470                                                           -3
# 2022000470                                                           -3
#
#                                     Nome da unidade gestora pagadora  \
# Identificador do processo de viagem
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# 17503013                                                    Sigilosa
# ...                                                              ...
# 18394132                                                    Sigilosa
# 2022000469                                                  Inválido
# 2022000469                                                  Inválido
# 2022000470                                                  Inválido
# 2022000470                                                  Inválido
#
#                                     Tipo de pagamento    Valor
# Identificador do processo de viagem
# 17503013                                      DIÁRIAS   100,30
# 17503013                                      DIÁRIAS   633,91
# 17503013                                      DIÁRIAS  2781,70
# 17503013                                      DIÁRIAS  2758,97
# 17503013                                      DIÁRIAS  1614,18
# ...                                               ...      ...
# 18394132                                      DIÁRIAS   129,63
# 2022000469                                    DIÁRIAS   969,88
# 2022000469                                RESTITUIÇÃO   272,50
# 2022000470                                RESTITUIÇÃO   272,50
# 2022000470                                    DIÁRIAS   969,88
#
# [111041 rows x 9 columns]

# %% [markdown]
# Subistituindo valores nulos por "Não infomado"

# %%
df['Nome do órgao pagador'] = df['Nome do órgao pagador'].fillna("Não informado") 

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Número da Proposta (PCDP), Código do órgão superior, Nome do órgão superior, Codigo do órgão pagador, Nome do órgao pagador, Código da unidade gestora pagadora, Nome da unidade gestora pagadora, Tipo de pagamento, Valor]
# Index: []

# %% [markdown]
# Salvando os dados limpos no arquivo

# %%
df.to_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/2022_Viagem.csv', index=False)
