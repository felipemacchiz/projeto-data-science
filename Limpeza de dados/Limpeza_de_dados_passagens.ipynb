# %% [markdown]
# Leitura e limpeza de dados
#
# Arquivo que contem as viagens

# %%
#importing libraries
import pandas as pd

# %matplotlib inline

# %%
# Resposta:

from google.colab import drive
drive.mount('/content/drive')

# lê o arquivo CSV
df = pd.read_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/2022_Passagem.csv', encoding='latin-1', sep=';')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Índices
#
# Definindo indice para o ordenação

# %%
df = df.set_index('Identificador do processo de viagem')
df = df.sort_index()

df
# Out:
#                                     Número da Proposta (PCDP)  \
# Identificador do processo de viagem
# 17563956                                         000002/22-2C
# 17563956                                         000002/22-2C
# 17563956                                         000002/22-2C
# 17563956                                         000002/22-2C
# 17564009                                         000001/22-2C
# ...                                                       ...
# 2022000494                                     Sem informação
# 2022000496                                     Sem informação
# 2022000496                                     Sem informação
# 2022000542                                     Sem informação
# 2022000542                                     Sem informação
#
#                                     Meio de transporte País - Origem ida  \
# Identificador do processo de viagem
# ...

# %% [markdown]
# # Verificando informações do arquivo e conferindo se o Dtype esta correto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166768 entries, 17563956 to 2022000542
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Número da Proposta (PCDP)  166768 non-null  object
#  1   Meio de transporte         166768 non-null  object
#  2   País - Origem ida          166768 non-null  object
#  3   UF - Origem ida            161683 non-null  object
#  4   Cidade - Origem ida        166768 non-null  object
#  5   País - Destino ida         166768 non-null  object
#  6   UF - Destino ida           160189 non-null  object
#  7   Cidade - Destino ida       166768 non-null  object
#  8   País - Origem volta        166768 non-null  object
#  9   UF - Origem volta          165217 non-null  object
#  10  Cidade - Origem volta      166768 non-null  object
#  11  Pais - Destino volta       166768 non-null  object
#  12  UF - Destino volta         166494 non-null  object
# ...

# %% [markdown]
# Convertendo colunas do tipo String para seus valores corretos, como data e numerico (Não consegui converter Object para numerico).

# %%
df['Data da emissão/compra'] = pd.to_datetime(df['Data da emissão/compra'])

# for valores in ['Valor da passagem','Taxa de serviço',Hora da emissão/compra']:
#   df[valores] = pd.to_numeric(df[valores], errors='ignore')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166768 entries, 17563956 to 2022000542
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Número da Proposta (PCDP)  166768 non-null  object
#  1   Meio de transporte         166768 non-null  object
#  2   País - Origem ida          166768 non-null  object
#  3   UF - Origem ida            161683 non-null  object
#  4   Cidade - Origem ida        166768 non-null  object
#  5   País - Destino ida         166768 non-null  object
#  6   UF - Destino ida           160189 non-null  object
#  7   Cidade - Destino ida       166768 non-null  object
#  8   País - Origem volta        166768 non-null  object
#  9   UF - Origem volta          165217 non-null  object
#  10  Cidade - Origem volta      166768 non-null  object
#  11  Pais - Destino volta       166768 non-null  object
#  12  UF - Destino volta         166494 non-null  object
# ...

# %% [markdown]
# Apresenta linhas com NaN no arquivo

# %%
df[df.isna().any(axis=1)]
# Out:
#                                     Número da Proposta (PCDP)  \
# Identificador do processo de viagem
# 17569036                                         000002/22-3C
# 17582605                                            000003/22
# 17582617                                            000004/22
# 17582629                                            000005/22
# 17582631                                            000006/22
# ...                                                       ...
# 2022000494                                     Sem informação
# 2022000496                                     Sem informação
# 2022000496                                     Sem informação
# 2022000542                                     Sem informação
# 2022000542                                     Sem informação
#
#                                     Meio de transporte País - Origem ida  \
# Identificador do processo de viagem
# ...

# %% [markdown]
# Subistituindo valores nulos por "Não infomado"

# %%
df['UF - Origem ida'] = df['UF - Origem ida'].fillna("Não informado") 
df['UF - Destino ida'] = df['UF - Destino ida'].fillna("Não informado")
df['UF - Origem volta'] = df['UF - Origem volta'].fillna("Não informado")
df['UF - Destino volta'] = df['UF - Destino volta'].fillna("Não informado")
df['Data da emissão/compra'] = df['Data da emissão/compra'].fillna("Não informado")

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Número da Proposta (PCDP), Meio de transporte, País - Origem ida, UF - Origem ida, Cidade - Origem ida, País - Destino ida, UF - Destino ida, Cidade - Destino ida, País - Origem volta, UF - Origem volta, Cidade - Origem volta, Pais - Destino volta, UF - Destino volta, Cidade - Destino volta, Valor da passagem, Taxa de serviço, Data da emissão/compra, Hora da emissão/compra]
# Index: []

# %% [markdown]
# Salvando os dados limpos no arquivo

# %%
df.to_csv('/content/drive/MyDrive/UP/Ciência de Dados/Notebooks/data/2022_Viagem.csv', index=False)
