# %% [markdown]
# Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
# %matplotlib inline

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Lendo arquivo

# %%
df = pd.read_csv('/content/drive/MyDrive/UP/Ciência de Dados/DATASET/2022Viagem.csv', engine='python' , encoding='utf8', sep=';')
df
# Out:
#        Identificador do processo de viagem N?mero da Proposta (PCDP)  \
# 0                                 17438343                 000001/22
# 1                                 17503013           Informa??es pro
# 2                                 17563956              000002/22-2C
# 3                                 17564009              000001/22-2C
# 4                                 17569036              000002/22-3C
# ...                                    ...                       ...
# 35443                             17865569                 000032/22
# 35444                             17865570              002012/22-1C
# 35445                             17865571           Informa??es pro
# 35446                             17865572              001651/22-1C
# 35447                             17865573                 001661/22
#
#         Situa??o Viagem Urgente  \
# 0      Realizada            N?O
# 1      Realizada            N?O
# 2      Realizada            SIM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35448 entries, 0 to 35447
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Identificador do processo de viagem  35448 non-null  int64
#  1   N?mero da Proposta (PCDP)            35448 non-null  object
#  2   Situa??o                             35448 non-null  object
#  3   Viagem Urgente                       35448 non-null  object
#  4   Justificativa Urg?ncia Viagem        35447 non-null  object
#  5   C?digo do ?rg?o superior             35447 non-null  float64
#  6   Nome do ?rg?o superior               35447 non-null  object
#  7   C?digo ?rg?o solicitante             35447 non-null  float64
#  8   Nome ?rg?o solicitante               35447 non-null  object
#  9   CPF viajante                         35445 non-null  object
#  10  Nome                                 35447 non-null  object
# ...

# %%
df[df['Fun??o'] == '-1']
# Out:
#        Identificador do processo de viagem N?mero da Proposta (PCDP)  \
# 0                                 17438343                 000001/22
# 2                                 17563956              000002/22-2C
# 3                                 17564009              000001/22-2C
# 5                                 17582605                 000003/22
# 6                                 17582617                 000004/22
# ...                                    ...                       ...
# 35437                             17865561                 001367/22
# 35438                             17865562                 000180/22
# 35440                             17865564                 002054/22
# 35444                             17865570              002012/22-1C
# 35446                             17865572              001651/22-1C
#
#         Situa??o Viagem Urgente  \
# 0      Realizada            N?O
# 2      Realizada            SIM
# 3      Realizada            SIM
# ...

# %%
deleteIndex = df[df['Fun??o'] == '-1'].index
deleteIndexNone = df[df['Fun??o'] == 'None'].index

for funcao in deleteIndex:
    df = df.drop(funcao)

# Esse aqui foi no olhometro
df = df.drop(35447)


df
# Out:
#        Identificador do processo de viagem N?mero da Proposta (PCDP)  \
# 1                                 17503013           Informa??es pro
# 4                                 17569036              000002/22-3C
# 11                                17620401                 000001/22
# 12                                17620488                 000002/22
# 14                                17634205                 000007/22
# ...                                    ...                       ...
# 35439                             17865563                 002014/22
# 35441                             17865565                 002280/22
# 35442                             17865568                 003186/22
# 35443                             17865569                 000032/22
# 35445                             17865571           Informa??es pro
#
#         Situa??o Viagem Urgente  \
# 1      Realizada            N?O
# 4      Realizada            SIM
# 11     Realizada            N?O
# ...

# %%
dfViagensUrgente = deleteIndexNone = df[df['Viagem Urgente'] == 'SIM']
dfViagensUrgente
# Out:
#        Identificador do processo de viagem N?mero da Proposta (PCDP)  \
# 4                                 17569036              000002/22-3C
# 36                                17667085                 000010/22
# 37                                17667216                 000011/22
# 38                                17667246                 000012/22
# 39                                17667268                 000013/22
# ...                                    ...                       ...
# 35431                             17865554                 004039/22
# 35432                             17865555                 002746/22
# 35439                             17865563                 002014/22
# 35442                             17865568                 003186/22
# 35443                             17865569                 000032/22
#
#         Situa??o Viagem Urgente  \
# 4      Realizada            SIM
# 36     Realizada            SIM
# 37     Realizada            SIM
# ...

# %% [markdown]
# Informações das viagens urgentes

# %%
dfViagensUrgente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9116 entries, 4 to 35443
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Identificador do processo de viagem  9116 non-null   int64
#  1   N?mero da Proposta (PCDP)            9116 non-null   object
#  2   Situa??o                             9116 non-null   object
#  3   Viagem Urgente                       9116 non-null   object
#  4   Justificativa Urg?ncia Viagem        9116 non-null   object
#  5   C?digo do ?rg?o superior             9116 non-null   float64
#  6   Nome do ?rg?o superior               9116 non-null   object
#  7   C?digo ?rg?o solicitante             9116 non-null   float64
#  8   Nome ?rg?o solicitante               9116 non-null   object
#  9   CPF viajante                         9116 non-null   object
#  10  Nome                                 9116 non-null   object
# ...

# %%
selecaoEscolhida = dfViagensUrgente[['Identificador do processo de viagem' , 'N?mero da Proposta (PCDP)', 'Situa??o', 'CPF viajante', 'Nome', 'Per?odo - Data de in?cio', 'Per?odo - Data de fim', 'Destinos', 'Motivo' ,'Valor di?rias', 'Valor outros gastos']]

selecaoEscolhida
# Out:
#        Identificador do processo de viagem N?mero da Proposta (PCDP)  \
# 4                                 17569036              000002/22-3C
# 36                                17667085                 000010/22
# 37                                17667216                 000011/22
# 38                                17667246                 000012/22
# 39                                17667268                 000013/22
# ...                                    ...                       ...
# 35431                             17865554                 004039/22
# 35432                             17865555                 002746/22
# 35439                             17865563                 002014/22
# 35442                             17865568                 003186/22
# 35443                             17865569                 000032/22
#
#         Situa??o    CPF viajante                             Nome  \
# 4      Realizada  ***.272.667-**  MARCIO EDWARD DE LIMA GONCALVES
# ...

# %%
selecaoEscolhida[selecaoEscolhida.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Identificador do processo de viagem, N?mero da Proposta (PCDP), Situa??o, CPF viajante, Nome, Per?odo - Data de in?cio, Per?odo - Data de fim, Destinos, Motivo, Valor di?rias, Valor outros gastos]
# Index: []

# %%
selecaoGroupedA = selecaoEscolhida.groupby(['CPF viajante','Destinos']).mean()
selecaoGroupedA
# Out:
#                                     Identificador do processo de viagem
# CPF viajante   Destinos
# ***.000.031-** Buriti Alegre/GO                              17808805.0
#                Macap?/AP                                     17814546.0
# ***.000.367-** Fortaleza/CE                                  17845062.0
# ***.000.632-** Nova Mamor?/RO                                17852423.0
# ***.000.911-** Belo Horizonte/MG                             17856020.0
# ...                                                                 ...
# ***.999.229-** Paranagu?/PR                                  17817808.0
# ***.999.435-** S?o Gabriel/BA                                17858287.0
# ***.999.783-** Itatira/CE                                    17847324.0
# ***.999.947-** Riad/Ar?bia Saudita                           17858878.0
#                Rio de Janeiro/RJ                             17850867.0
#
# [8591 rows x 1 columns]
